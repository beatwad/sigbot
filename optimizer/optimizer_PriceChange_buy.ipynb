# %% [markdown]
# # Best optimizer parameters:
#
# ### BUY ~ 71.15%
# - PriceChange: low_price_quantile **10**
#
# # Parameter optimization

# %%
import sys
import pandas as pd
import numpy as np
from optimizer import Optimizer
from os import environ


# Set environment variable
environ["ENV"] = "optimize"

from bot.bot import SigBot
from config.config import ConfigFactory

# Get configs
configs = ConfigFactory.factory(environ).configs


pd.set_option('display.max_columns', 500)

ttype = 'buy'
pattern = ['PriceChange']
opt_limit = 100
load = False

optim_dict = {'PriceChange': {"low_price_quantile": [1 * (i +  1) for i in range(10)]}}
opt = Optimizer(pattern, optim_dict, **configs)

stat = opt.optimize(pattern, ttype, opt_limit, load)
try:
    open(f'opt_{"_".join(pattern)}_{ttype}.pkl', 'w').close()
except FileNotFoundError:
    pass
stat.to_pickle(f'opt_{"_".join(pattern)}_{ttype}.pkl')

stat['pct_right_forecast_avg'] = stat[[f'pct_right_forecast_{lag + 1}' for lag in range(24)]].apply(np.mean, axis=1)
stat = stat.sort_values(['pct_right_forecast_avg', 'forecasts_num'], ascending=False)
stat[stat['forecasts_num'] > 10].head(20)
# Out:
# Number of combinations is 10
#   0%|          | 0/10 [00:00<?, ?it/s]
#        pattern  PriceChange_low_price_quantile  pct_right_forecast_1  \
# 9  PriceChange                              10                 98.08
# 8  PriceChange                               9                 97.78
# 5  PriceChange                               6                100.00
# 6  PriceChange                               7                100.00
# 7  PriceChange                               8                100.00
# 4  PriceChange                               5                100.00
# 3  PriceChange                               4                100.00
# 0  PriceChange                               1                100.00
# 2  PriceChange                               3                100.00
#
#    pct_right_forecast_2  pct_right_forecast_3  pct_right_forecast_4  \
# 9                 76.92                 53.85                 53.85
# 8                 73.33                 51.11                 51.11
# 5                 66.67                 45.45                 51.52
# 6                 68.57                 48.57                 51.43
# 7                 66.67                 47.22                 50.00
# 4                 61.54                 42.31                 50.00
# 3                 63.16                 52.63                 57.89
# 0                 58.82                 47.06                 58.82
# 2                 61.54                 38.46                 38.46
#
#    pct_right_forecast_5  pct_right_forecast_6  pct_right_forecast_7  \
# 9                 57.69                 59.62                 67.31
# 8                 53.33                 55.56                 64.44
# 5                 51.52                 54.55                 57.58
# 6                 54.29                 57.14                 62.86
# 7                 52.78                 55.56                 61.11
# 4                 50.00                 53.85                 57.69
# 3                 57.89                 57.89                 57.89
# 0                 52.94                 52.94                 52.94
# 2                 53.85                 46.15                 46.15
#
#    pct_right_forecast_8  pct_right_forecast_9  pct_right_forecast_10  \
# 9                 69.23                 67.31                  67.31
# 8                 66.67                 64.44                  64.44
# 5                 63.64                 63.64                  60.61
# 4              0.18             -0.36              0.17              0.05
# 3              0.89              0.29              0.49              0.61
# 0              1.27             -0.24              0.58              0.55
# 2              0.89             -0.27             -0.94              0.55
#
#    pct_price_diff_6  pct_price_diff_7  pct_price_diff_8  pct_price_diff_9  \
# 9              1.48              1.58              3.01              2.66
# 8              1.39              1.39              2.96              2.64
# 5              1.03              0.86              1.75              2.33
# 6              1.39              1.55              1.75              1.85
# 7              1.21              1.35              1.50              1.45
# 4              0.91              0.55              1.05              0.70
# 3              1.74              0.86              0.35              0.26
# 0              1.74              0.25             -0.25             -1.43
# 2             -0.45             -1.19             -1.44             -1.75
#
#    pct_price_diff_10  pct_price_diff_11  pct_price_diff_12  pct_price_diff_13  \
# 9               3.17               3.74               3.86               4.66
# 8               2.71               3.79               3.96               5.30
# 5               2.19               2.96               3.34               3.79
# 6               2.19               2.57               3.20               3.30
# 7               2.09               2.52               2.94               3.30
# 4               2.10               2.36               2.41               3.30
# 3               0.33               0.38               0.00               3.25
# 0              -0.46               0.08              -0.08               2.90
# 2              -2.11              -1.89              -0.48               2.49
#
#    pct_price_diff_14  pct_price_diff_15  pct_price_diff_16  pct_price_diff_17  \
# 9               5.33               5.59               5.30               5.61
# 8               5.57               5.51               5.08               5.50
# 5               4.28               4.89               4.30               5.50
# 6               4.85               4.89               4.30               5.50
# 7               4.44               4.83               4.13               5.23
# 4               4.17               5.45               4.60               5.40
# 3               2.99               4.89               4.30               4.96
# 0               2.90               4.77               3.82               4.53
# 2               2.90               4.77               3.82               4.53
#
#    pct_price_diff_18  pct_price_diff_19  pct_price_diff_20  pct_price_diff_21  \
# 9               7.00               7.03               7.28               6.91
# 8               7.38               7.61               7.60               7.08
# 5               7.38               7.08               7.79               7.55
# 6               7.38               7.08               7.79               7.55
# 7               6.83               6.84               7.67               7.31
# 4               5.82               6.06               6.80               6.92
# 3               5.35               5.40               6.05               5.83
# 0               4.75               4.54               5.66               5.72
# 2               4.75               4.54               5.66               5.72
#
#    pct_price_diff_22  pct_price_diff_23  pct_price_diff_24  forecasts_num  \
# 9               7.11               7.09               7.13             52
# 8               7.56               7.31               7.31             45
# 5               6.83               7.31               7.31             33
# 6               6.83               7.31               7.31             35
# 7               6.81               7.20               6.90             36
# 4               6.45               6.86               6.90             26
# 3               5.52               6.28               6.32             19
# 0               5.38               4.84               5.01             17
# 2               5.38               4.84               5.01             13
#
#    pct_right_forecast_avg
# 9               71.155000
# 8               69.165417
# 5               66.922083
# 6               66.667083
# 7               65.045417
# 4               64.583333
# 3               64.471667
# 0               60.540000
# 2               55.769167
