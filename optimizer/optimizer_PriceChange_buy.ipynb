# %% [markdown]
# # Timer

# %%
from time import sleep
from datetime import datetime

month, day, hour, minute = 10, 22, 13, 30

while True:
    dt = datetime.now()
    if dt.month >= month and dt.day >= day:
        if dt.hour > hour or (dt.hour == hour and dt.minute > minute):
            break
    sleep(60)

# %% [markdown]
# # Parameter optimization

# %%
import sys
import pandas as pd
import numpy as np
from glob import glob
from optimizer import Optimizer
from os import environ

# Set environment variable
environ["ENV"] = "optimize"

from bot.bot import SigBot
from config.config import ConfigFactory

pd.set_option('display.max_columns', 500)

ttype = 'buy'
pattern = ['PriceChange']
work_timeframe = '15m'
higher_timeframe = '4h'
opt_limit = 50
load = False

# Get configs
configs = ConfigFactory.factory(environ).configs
configs['Timeframes']['work_timeframe'] = work_timeframe
configs['Timeframes']['higher_timeframe'] = higher_timeframe

optim_dict = {'PriceChange': {"low_price_quantile": [1 * (i + 1) for i in range(20)]}}

opt = Optimizer(pattern, optim_dict, **configs)
stat = opt.optimize(pattern, ttype, opt_limit, load)

stat_list = glob(f'opt_{"_".join(pattern)}_{ttype}_{work_timeframe}_{higher_timeframe}*')
if not stat_list:
    stat.to_pickle(f'opt_{"_".join(pattern)}_{ttype}_{work_timeframe}_{higher_timeframe}.pkl')
else:
    stat.to_pickle(f'opt_{"_".join(pattern)}_{ttype}_{work_timeframe}_{higher_timeframe}_{len(stat_list)}.pkl')

stat['pct_right_forecast_avg'] = stat[[f'pct_right_forecast_{lag + 1}' for lag in range(24)]].apply(np.mean, axis=1)
stat['indicator_rank'] = (stat['pct_right_forecast_avg'] - 70) * stat['forecasts_num']
stat = stat.sort_values(['indicator_rank', 'pct_right_forecast_avg'], ascending=False)
stat.head(20)
# Out:
# Number of combinations is 20
#   0%|          | 0/20 [00:00<?, ?it/s]
#         pattern  PriceChange_low_price_quantile  pct_right_forecast_1  \
# 0   PriceChange                               1                 100.0
# 1   PriceChange                               2                 100.0
# 2   PriceChange                               3                 100.0
# 3   PriceChange                               4                 100.0
# 4   PriceChange                               5                 100.0
# 5   PriceChange                               6                 100.0
# 7   PriceChange                               8                 100.0
# 15  PriceChange                              16                 100.0
# 6   PriceChange                               7                 100.0
# 11  PriceChange                              12                 100.0
# 12  PriceChange                              13                 100.0
# 13  PriceChange                              14                 100.0
# 14  PriceChange                              15                 100.0
# 8   PriceChange                               9                 100.0
# 9   PriceChange                              10                 100.0
# 10  PriceChange                              11                 100.0
# 16  PriceChange                              17                 100.0
# 17  PriceChange                              18                 100.0
# 18  PriceChange                              19                 100.0
# 19  PriceChange                              20                 100.0
#
#     pct_right_forecast_2  pct_right_forecast_3  pct_right_forecast_4  \
# 0                 100.00                100.00                100.00
# 1                 100.00                100.00                100.00
# 2                 100.00                100.00                100.00
# 3                 100.00                100.00                100.00
# 4                 100.00                100.00                 50.00
# 5                 100.00                100.00                 50.00
# 7                  75.00                 75.00                 50.00
# 15                 62.50                 62.50                 50.00
# 6                  66.67                 66.67                 33.33
# 11                 57.14                 57.14                 42.86
# 12                 57.14                 57.14                 42.86
# 13                 57.14                 57.14                 42.86
# 14                 57.14                 57.14                 42.86
# 8                  80.00                 80.00                 40.00
# 9                  66.67                 66.67                 33.33
# 10                 50.00                 50.00                 33.33
# 16                 70.00                 60.00                 50.00
# 17                 70.00                 60.00                 50.00
# 18                 70.00                 60.00                 50.00
# 19                 70.00                 60.00                 50.00
#
#     pct_right_forecast_5  pct_right_forecast_6  pct_right_forecast_7  \
# 0                 100.00                100.00                100.00
# 1                 100.00                100.00                100.00
# 2                 100.00                100.00                100.00
# 3                 100.00                100.00                100.00
# 4                  50.00                 50.00                 50.00
# 5                  50.00                 50.00                 50.00
# 7                  75.00                 75.00                 50.00
# 15                 62.50                 62.50                 50.00
# 6                  66.67                 66.67                 33.33
# 11                 57.14                 57.14                 42.86
# 12                 57.14                 57.14                 42.86
# 13                 57.14                 57.14                 42.86
# 14                 57.14                 57.14                 42.86
# 8                  60.00                 60.00                 40.00
# 9                  50.00                 50.00                 33.33
# 10                 50.00                 50.00                 33.33
# 16                 60.00                 60.00                 50.00
# 17                 60.00                 60.00                 50.00
# 18                 60.00                 60.00                 50.00
# 19                 60.00                 60.00                 50.00
#
#     pct_right_forecast_8  pct_right_forecast_9  pct_right_forecast_10  \
# 0                 100.00                100.00                 100.00
# 1                 100.00                100.00                 100.00
# 2                 100.00                100.00                 100.00
# 3                 100.00                100.00                 100.00
# 4                  50.00                 50.00                  50.00
# 5                  50.00                 50.00                  50.00
# 7                  50.00                 50.00                  50.00
# 15                 50.00                 50.00                  50.00
# 6                  33.33                 33.33                  33.33
# 11                 42.86                 42.86                  42.86
# 12                 42.86                 42.86                  42.86
# 13                 42.86                 42.86                  42.86
# 14                 42.86                 42.86                  42.86
# 8                  40.00                 40.00                  40.00
# 9                  33.33                 33.33                  33.33
# 10                 33.33                 33.33                  33.33
# 16                 50.00                 50.00                  50.00
# 17                 50.00                 50.00                  50.00
# 18                 50.00                 50.00                  50.00
# 19                 50.00                 50.00                  50.00
#
#     pct_right_forecast_11  pct_right_forecast_12  pct_right_forecast_13  \
# 0                  100.00                 100.00                 100.00
# 1                  100.00                 100.00                 100.00
# 2                  100.00                 100.00                 100.00
# 3                  100.00                 100.00                 100.00
# 4                   50.00                 100.00                 100.00
# 5                   50.00                 100.00                 100.00
# 7                   50.00                  75.00                  75.00
# 15                  62.50                  75.00                  75.00
# 6                   33.33                  66.67                  66.67
# 11                  57.14                  71.43                  71.43
# 12                  57.14                  71.43                  71.43
# 13                  57.14                  71.43                  71.43
# 14                  57.14                  71.43                  71.43
# 8                   40.00                  80.00                  80.00
# 9                   50.00                  83.33                  83.33
# 10                  50.00                  66.67                  66.67
# 16                  60.00                  70.00                  70.00
# 17                  60.00                  70.00                  70.00
# 18                  60.00                  70.00                  70.00
# 19                  60.00                  70.00                  70.00
#
#     pct_right_forecast_14  pct_right_forecast_15  pct_right_forecast_16  \
# 0                  100.00                 100.00                 100.00
# 1                  100.00                 100.00                 100.00
# 2                  100.00                 100.00                 100.00
# 3                  100.00                 100.00                 100.00
# 4                  100.00                 100.00                 100.00
# 5                  100.00                 100.00                 100.00
# 7                   75.00                  75.00                  75.00
# 15                  75.00                  75.00                  75.00
# 6                   66.67                  66.67                  66.67
# 11                  71.43                  71.43                  71.43
# 12                  71.43                  71.43                  71.43
# 13                  71.43                  71.43                  71.43
# 14                  71.43                  71.43                  71.43
# 8                   80.00                  60.00                  60.00
# 9                   83.33                  66.67                  66.67
# 10                  66.67                  66.67                  66.67
# 16                  70.00                  60.00                  60.00
# 17                  70.00                  60.00                  60.00
# 18                  70.00                  60.00                  60.00
# 19                  70.00                  60.00                  60.00
#
#     pct_right_forecast_17  pct_right_forecast_18  pct_right_forecast_19  \
# 0                  100.00                 100.00                 100.00
# 1                  100.00                 100.00                 100.00
# 2                  100.00                 100.00                 100.00
# 3                  100.00                 100.00                 100.00
# 4                   50.00                 100.00                 100.00
# 5                   50.00                 100.00                 100.00
# 7                   50.00                  75.00                  75.00
# 15                  62.50                  75.00                  75.00
# 6                   33.33                  66.67                  66.67
# 11                  57.14                  71.43                  71.43
# 12                  57.14                  71.43                  71.43
# 13                  57.14                  71.43                  71.43
# 14                  57.14                  71.43                  71.43
# 8                   40.00                  60.00                  60.00
# 9                   50.00                  66.67                  66.67
# 10                  50.00                  66.67                  66.67
# 16                  50.00                  70.00                  70.00
# 17                  50.00                  70.00                  70.00
# 18                  50.00                  70.00                  70.00
# 19                  50.00                  70.00                  70.00
#
#     pct_right_forecast_20  pct_right_forecast_21  pct_right_forecast_22  \
# 0                  100.00                 100.00                 100.00
# 1                  100.00                 100.00                 100.00
# 2                  100.00                 100.00                 100.00
# 3                  100.00                 100.00                 100.00
# 4                  100.00                 100.00                 100.00
# 5                  100.00                 100.00                 100.00
# 7                   75.00                  75.00                  75.00
# 15                  75.00                  75.00                  75.00
# 6                   66.67                  66.67                  66.67
# 11                  71.43                  71.43                  71.43
# 12                  71.43                  71.43                  71.43
# 13                  71.43                  71.43                  71.43
# 14                  71.43                  71.43                  71.43
# 8                   60.00                  60.00                  60.00
# 9                   66.67                  66.67                  66.67
# 10                  66.67                  66.67                  66.67
# 16                  70.00                  60.00                  60.00
# 17                  70.00                  60.00                  60.00
# 18                  70.00                  60.00                  60.00
# 19                  70.00                  60.00                  60.00
#
#     pct_right_forecast_23  pct_right_forecast_24  pct_price_diff_1  \
# 0                  100.00                 100.00              4.47
# 1                  100.00                 100.00              4.47
# 2                  100.00                 100.00              4.47
# 3                  100.00                 100.00              4.47
# 4                   50.00                 100.00              3.03
# 5                   50.00                 100.00              3.03
# 7                   50.00                  75.00              3.03
# 15                  62.50                  75.00              2.79
# 6                   33.33                  66.67              1.58
# 11                  57.14                  71.43              1.58
# 12                  57.14                  71.43              1.58
# 13                  57.14                  71.43              1.58
# 14                  57.14                  71.43              1.58
# 8                   40.00                  60.00              1.58
# 9                   50.00                  66.67              1.04
# 10                  50.00                  66.67              0.96
# 16                  50.00                  60.00              2.01
# 17                  50.00                  60.00              2.01
# 18                  50.00                  60.00              2.01
# 19                  50.00                  60.00              2.01
#
#     pct_price_diff_2  pct_price_diff_3  pct_price_diff_4  pct_price_diff_5  \
# 0               6.52              0.57              3.03              2.05
# 1               6.52              0.57              3.03              2.05
# 2               6.52              0.57              3.03              2.05
# 3               6.52              0.57              3.03              2.05
# 4               3.98              0.65              1.22              0.63
# 5               3.98              0.65              1.22              0.63
# 7               3.98              0.65              1.46              1.08
# 15              3.64              0.65              1.46              1.08
# 6               1.44              0.57             -0.12              0.12
# 11              1.44              0.57             -0.12              0.12
# 12              1.44              0.57             -0.12              0.12
# 13              1.44              0.57             -0.12              0.12
# 14              1.44              0.57             -0.12              0.12
# 8               1.44              0.57             -0.12              0.12
# 9               0.92              0.39             -0.26             -0.34
# 10              0.67              0.23             -0.26             -0.34
# 16              2.43              0.65              1.46              1.08
# 17              2.43              0.65              1.46              1.08
# 18              2.43              0.65              1.46              1.08
# 19              2.43              0.65              1.46              1.08
#
#     pct_price_diff_6  pct_price_diff_7  pct_price_diff_8  pct_price_diff_9  \
# 0               8.20              8.65              4.72              5.33
# 1               8.20              8.65              4.72              5.33
# 2               8.20              8.65              4.72              5.33
# 3               8.20              8.65              4.72              5.33
# 4               3.52              4.14              1.69              1.72
# 5               3.52              4.14              1.69              1.72
# 7               4.33              4.33              2.01              2.20
# 15              3.13              4.33              2.01              2.20
# 6               0.46              0.00             -0.69             -0.92
# 11              0.46              0.00             -0.69             -0.92
# 12              0.46              0.00             -0.69             -0.92
# 13              0.46              0.00             -0.69             -0.92
# 14              0.46              0.00             -0.69             -0.92
# 8               0.46              0.00             -0.60             -0.70
# 9              -0.35             -0.19             -0.65             -0.81
# 10             -0.35             -0.19             -0.70             -1.06
# 16              3.13              3.46              2.01              2.20
# 17              3.13              3.46              2.01              2.20
# 18              3.13              3.46              2.01              2.20
# 19              3.13              3.46              2.01              2.20
#
#     pct_price_diff_10  pct_price_diff_11  pct_price_diff_12  \
# 0                8.04               7.63              12.51
# 1                8.04               7.63              12.51
# 2                8.04               7.63              12.51
# 3                8.04               7.63              12.51
# 4                3.18               3.54               6.44
# 5                3.18               3.54               6.44
# 7                3.56               3.54               6.44
# 15               3.73               5.19               8.48
# 6               -0.92              -0.55               0.38
# 11              -0.58               2.74               4.45
# 12              -0.58               2.74               4.45
# 13              -0.58               2.74               4.45
# 14              -0.58               2.74               4.45
# 8               -0.10               0.00               0.38
# 9               -0.34               1.37               2.41
# 10              -0.75               1.10               2.41
# 16               1.24               3.62               4.23
# 17               1.24               3.62               4.23
# 18               1.24               3.62               4.23
# 19               1.24               3.62               4.23
#
#     pct_price_diff_13  pct_price_diff_14  pct_price_diff_15  \
# 0               18.08              19.31              20.71
# 1               18.08              19.31              20.71
# 2               18.08              19.31              20.71
# 3               18.08              19.31              20.71
# 4                9.20              10.34              10.75
# 5                9.20              10.34              10.75
# 7                9.20              10.34              10.75
# 15              11.80              12.04              13.59
# 6                0.31               1.38               0.79
# 11               5.52               5.30               6.48
# 12               5.52               5.30               6.48
# 13               5.52               5.30               6.48
# 14               5.52               5.30               6.48
# 8                0.31               1.38               0.79
# 9                2.91               3.34               3.63
# 10               2.91               3.34               3.63
# 16               3.66               3.34               3.63
# 17               3.66               3.34               3.63
# 18               3.66               3.34               3.63
# 19               3.66               3.34               3.63
#
#     pct_price_diff_16  pct_price_diff_17  pct_price_diff_18  \
# 0               17.88              18.82              20.34
# 1               17.88              18.82              20.34
# 2               17.88              18.82              20.34
# 3               17.88              18.82              20.34
# 4                9.30               9.27              10.34
# 5                9.30               9.27              10.34
# 7                9.30               9.27              10.34
# 15              10.76              11.08              11.25
# 6                0.72              -0.28               0.34
# 11               3.65               3.35               2.17
# 12               3.65               3.35               2.17
# 13               3.65               3.35               2.17
# 14               3.65               3.35               2.17
# 8                0.72              -0.28               0.34
# 9                2.19               1.54               1.26
# 10               2.19               1.54               1.26
# 16               2.19               1.61               1.26
# 17               2.19               1.61               1.26
# 18               2.19               1.61               1.26
# 19               2.19               1.61               1.26
#
#     pct_price_diff_19  pct_price_diff_20  pct_price_diff_21  \
# 0               24.68              24.23              24.19
# 1               24.68              24.23              24.19
# 2               24.68              24.23              24.19
# 3               24.68              24.23              24.19
# 4               12.72              12.36              12.30
# 5               12.72              12.36              12.30
# 7               12.72              12.36              12.30
# 15              13.48              12.36              12.40
# 6                0.76               0.48               0.41
# 11               2.28               0.48               0.60
# 12               2.28               0.48               0.60
# 13               2.28               0.48               0.60
# 14               2.28               0.48               0.60
# 8                0.76               0.48               0.41
# 9                1.52               0.41               0.51
# 10               1.52               0.41               0.51
# 16               1.52               0.41               0.51
# 17               1.52               0.41               0.51
# 18               1.52               0.41               0.51
# 19               1.52               0.41               0.51
#
#     pct_price_diff_22  pct_price_diff_23  pct_price_diff_24  forecasts_num  \
# 0               20.30              23.94              26.12              1
# 1               20.30              23.94              26.12              1
# 2               20.30              23.94              26.12              1
# 3               20.30              23.94              26.12              1
# 4               10.32              11.82              13.13              2
# 5               10.32              11.82              13.13              2
# 7               10.32              11.82              13.13              4
# 15              10.42              12.48              13.96              8
# 6                0.34              -0.31               0.14              3
# 11               0.55               1.02               1.81              7
# 12               0.55               1.02               1.81              7
# 13               0.55               1.02               1.81              7
# 14               0.55               1.02               1.81              7
# 8                0.34              -0.31               0.14              5
# 9                0.45               0.35               0.97              6
# 10               0.45               0.35               0.97              6
# 16               0.45               0.35               0.97             10
# 17               0.45               0.35               0.97             10
# 18               0.45               0.35               0.97             10
# 19               0.45               0.35               0.97             10
#
#     pct_right_forecast_avg  indicator_rank
# 0               100.000000       30.000000
# 1               100.000000       30.000000
# 2               100.000000       30.000000
# 3               100.000000       30.000000
# 4                79.166667       18.333333
# 5                79.166667       18.333333
# 7                67.708333       -9.166667
# 15               67.187500      -22.500000
# 6                56.945417      -39.163750
# 11               62.500417      -52.497083
# 12               62.500417      -52.497083
# 13               62.500417      -52.497083
# 14               62.500417      -52.497083
# 8                59.166667      -54.166667
# 9                59.722500      -61.665000
# 10               56.250833      -82.495000
# 16               61.666667      -83.333333
# 17               61.666667      -83.333333
# 18               61.666667      -83.333333
# 19               61.666667      -83.333333

# %% [markdown]
# # Save new config data to config file

# %%
from config_updater import ConfigUpdater

timeframe = f'{work_timeframe}_{higher_timeframe}'
        
optim_dict = {'PriceChange': {"low_price_quantile": [12]}}
        
cu = ConfigUpdater(ttype, timeframe)
cu.config_update(optim_dict)
